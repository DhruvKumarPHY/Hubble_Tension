# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/lucavisinelli/H0TensionRealm/main/data/dataset.csv")

# %%
data
# Out:
#    Direct/Indirect                                         Type  \
# 0         Indirect                              CMB with Planck
# 1         Indirect                              CMB with Planck
# 2         Indirect                              CMB with Planck
# 3         Indirect                              CMB with Planck
# 4         Indirect                           CMB without Planck
# 5         Indirect                           CMB without Planck
# 6         Indirect                           CMB without Planck
# 7         Indirect                           CMB without Planck
# 8         Indirect                           CMB without Planck
# 9         Indirect                             No CMB; with BBN
# 10        Indirect                             No CMB; with BBN
# 11        Indirect                             No CMB; with BBN
# 12        Indirect                          Pl(k) + CMB lensing
# 13          Direct                                Cepheids-SNIa
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.Value,data.Type,s=10)

# %%
import statistics as st

# %%
x = st.mean(data.Value)
x
# Out:
# 71.65625
